# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\yanna\Downloads\creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.shape[0]
# Out:
# 284807

# %%
df.shape[1]
# Out:
# 31

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
fraud=df[df['Class']==1]
valid=df[df['Class']==0]
outlierFraction=len(fraud)/float(len(valid))
print(outlierFraction)
print('Fraud cases :{}'.format(len(df[df['Class']==1])))
print('valid Transactions :{}'.format(len(df[df['Class']==0])))
# Out:
# 0.0017304750013189597
# Fraud cases :492
# valid Transactions :284315

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
sns.countplot(df['Class'])
# Out:
# <Axes: ylabel='count'>

# %%
corr=df.corr()
plt.figure(figsize=(30,20))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
df['Amount']=sc.fit_transform(pd.DataFrame(df["Amount"]))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df=df.drop(['Time'],axis=1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
df.shape
# Out:
# (284807, 30)

# %%
df.duplicated().any()
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
x=df.drop('Class',axis=1)

# %%
y=df["Class"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report,f1_score

# %%
y_pred1=log.predict(x_test)

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55042
#            1       0.89      0.63      0.74        91
#
#     accuracy                           1.00     55133
#    macro avg       0.95      0.81      0.87     55133
# weighted avg       1.00      1.00      1.00     55133

# %%
print('F1 score:',f1_score(y_test,y_pred1))
# Out:
# F1 score: 0.7354838709677419

# %%
from sklearn.metrics import confusion_matrix

# %%
Labels=['Normal','Fraud']

# %%
conf_matrix=confusion_matrix(y_test,y_pred1)

# %%
plt.figure(figsize=(10,10))
#sns.heatmap(conf_matrix, xticklabels = Labels,yticklabels=Labels,annot=True,fmt="d");

# %%
sns.heatmap(conf_matrix, xticklabels = Labels,yticklabels=Labels,annot=True,fmt="d");
plt.title('Confusion matrix')
plt.ylabel("True class")
plt.xlabel("Predicted class")
plt.show()

# %%
valid=df[df['Class']==0]
fraud=df[df["Class"]==1]

# %%
valid.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
valid_simple=valid.sample(n=473)

# %%
valid_simple.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([valid_simple,fraud],ignore_index=True)
new_data["Class"].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -2.188039  1.128496 -0.001162  0.268987  3.004944  0.417510  1.835374
# 1 -0.403999  0.995309  0.699144  0.424865  0.881304  1.064906  0.199970
# 2 -0.047016  1.049828 -0.356599 -0.640039  0.951627 -0.591940  0.879431
# 3  1.248181 -1.143166  1.736423 -0.233203 -2.080137  0.314319 -1.700046
# 4 -0.882856  0.335240  0.436011 -1.530078 -0.918777 -0.896242 -0.305724
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0 -5.577708  1.010958  2.956292  ...  2.759904 -0.276038 -0.539918 -0.034579
# 1  0.277613 -0.612790  0.081654  ... -0.198001 -0.702083 -0.198651 -1.769795
# 2 -0.029745 -0.304688 -0.564186  ... -0.260685 -0.665277  0.124081  0.670172
# 3  0.396330  0.548062  0.450152  ...  0.197419  0.852726 -0.071493  0.598589
# 4  0.371352  1.429037 -0.769602  ...  0.280287  0.922323  0.051488  0.101944
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
x=new_data.drop("Class",axis=1)

# %%
y=new_data["Class"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
log=LogisticRegression()

# %%
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred2=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9263157894736842

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9489795918367347

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.93

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.93

# %%
#plot the Roc Curve

# %%
from sklearn import metrics

# %%
y_pred_proba=log.predict_proba(x_test)[::1]

# %%
#fpr,tpr,_=metrics.roc_curve(y_test,y_pred_proba)

# %%
# Assuming y_pred_proba is the predicted probabilities for each class
# You should use the probabilities for the positive class (fraudulent transactions)
y_pred_proba_positive_class = y_pred_proba[:, 1]

# Now compute the ROC curve
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba_positive_class)

# %%
plt.plot(fpr,tpr)
plt.ylabel("True Positive rate")
plt.xlabel('False Positive Rate')
plt.show()

# %%
#claculate the AUC

# %%
import matplotlib.pyplot as plt

# %%
y_pred_proba=log.predict_proba(x_test)[::,1]
fpr,tpr,_=metrics.roc_curve(y_test,y_pred_proba)
auc=metrics.roc_auc_score(y_test,y_pred_proba)

# %%
#for Creating the curve We use 
#plt.plot(fpr,tpr,label="AUC="+str(auc))
#plt.ylabel("Treu Positive Rate")
#plt.xlabel("False Position Rate")
#plt.legend(log=4)
#plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have already computed fpr and tpr
plt.plot(fpr, tpr, label="ROC Curve")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.legend(loc=4)  # Use loc to specify the location of the legend
plt.show()

# %%
x=df.drop('Class',axis=1)

# %%
y=df["Class"]

# %%
x.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred3=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9992563437505668

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.890625

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.6263736263736264

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.7354838709677419

# %%
from sklearn import metrics #define Metrics

# %%
y_pred_proba = log.predict_proba(x_test)[::, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba)

# %%
plt.plot(fpr,tpr)
plt.ylabel("True Positive rate")
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# The improved performance of our model is now evident without oversampling, compared to our previous logistic regression.It's clear that our model performed significantly better without oversampling compared to our previous logistic regression. It is evident that our model performed significantly better without oversampling compared to the previous logistic regression.Thank you.
